# %%
print("hello")
# Out:
# hello

# %%
# os , math , re
import os

# %%
os.getcwd() ##
# Out:
# 'D:\\Data Science\\New folder\\Images\\BA- cellulitis'

# %%
os.listdir(r'c:\\Users\\kumaw\\OneDrive\\Desktop\\6 Month Data Science\\os')
# Out:
# ['hello', 'hello.txt', 'osmodule.ipynb']

# %%
path = r"D:\Data Science\New folder\Images\BA-impetigo"
os.listdir(path)
# Out:
# ['0_BA-impetigo (88).jpg',
#  '10_BA-impetigo (89).jpg',
#  '11_BA-impetigo (77).jpg',
#  '12_BA-impetigo (89).jpg',
#  '13_BA-impetigo (2).jpg',
#  '14_BA-impetigo (5).jpeg',
#  '15_BA-impetigo (38).jpg',
#  '16_BA-impetigo (5).jpg',
#  '17_BA-impetigo (66).jpg',
#  '18_BA-impetigo (82).jpg',
#  '19_BA-impetigo (4).png',
#  '1_BA-impetigo (60).jpg',
#  '20_BA-impetigo (50).jpg',
#  '21_BA-impetigo (64).jpg',
#  '22_BA-impetigo (55).jpg',
#  '23_BA-impetigo (43).jpg',
#  '24_BA-impetigo (67).jpg',
#  '25_BA-impetigo (48).jpg',
#  '26_BA-impetigo (73).jpg',
#  '27_BA-impetigo (54).jpg',
#  '28_BA-impetigo (6).jpeg',
#  '29_BA-impetigo (22).jpg',
#  '2_BA-impetigo (16).jpg',
#  '30_BA-impetigo (4).jpg',
#  '31_BA-impetigo (26).jpg',
#  '32_BA-impetigo (85).jpg',
#  '33_BA-impetigo (53).jpg',
#  '34_BA-impetigo (40).jpg',
#  '35_BA-impetigo (10).jpg',
#  '36_BA-impetigo (30).jpg',
#  '37_BA-impetigo (7).jpeg',
#  '38_BA-impetigo (60).jpg',
#  '39_BA-impetigo (55).jpg',
# ...

# %%
os.mkdir("dev")

# %%
os.makedirs(r"hello\hii\i\dev")

# %%
# os.remove(r"os\\dev")

# %%
os.getcwd()
# Out:
# 'D:\\Data Science\\New folder\\Images\\BA- cellulitis'

# %%
# os.chdir(r"D:\Data Science\New folder\Images\BA- cellulitis")

# %%
os.getcwd()
# Out:
# 'D:\\Data Science\\New folder\\Images\\BA- cellulitis'

# %%
# os.rmdir(r'C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os\dev')

# %%
# os.removedirs("path")

os.stat(r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os\hello.txt")
# Out:
# os.stat_result(st_mode=33206, st_ino=56294995342144021, st_dev=2762774790, st_nlink=1, st_uid=0, st_gid=0, st_size=18, st_atime=1779879615, st_mtime=1779879561, st_ctime=1779879554)

# %%
os.startfile(r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os\hello.txt")

# %%
import os

os.rename(
    r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os\hello.txt",
    r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os\dev.txt"
)

print("File Renamed Successfully")
# Out:
# File Renamed Successfully

# %%
import os

os.rename(
    r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\os",
    r"C:\Users\kumaw\OneDrive\Desktop\6 Month Data Science\OS Module"
)

print("File Renamed Successfully")
