# %%
Funtion Polymorphism
print(len("hello"))
print(len([2,3,4]))

# %%
# Method Polymorphism
class College:
    def show(self):
        print("hello hii kese ho ")
    def show(self):
        print("haan me tik hu")
        
College()

# %%
# Method Polymorphism
class College:
    def show(self):
        print("hello hii kese ho ")
        
class Student:
    def show(self):
        print("haan me tik hu")
        
College().show()
Student().show()

# %%
College().show()

# %%
# # operator polymorphism 
# 4+1
# "hello"+"jjbfjvjngj"
# [3,3,10,5,5,5,5]+[3,4,5]

# %%
### method overrindiing 
class Company:
    def details(self):
        print("sb log kam kr rhe ")
class Developer(Company):
    def details(self):
        print("developer is working")
Developer().details()
